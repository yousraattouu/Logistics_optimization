# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import time
from tqdm import tqdm_notebook
# %matplotlib inline
# %load_ext autoreload
# %autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from delivery import *

# %%
env = DeliveryEnvironment(n_arrets = 10)
# Out:
# Initialized Delivery Environment with 10 random stops
# Target metric for optimization is distance

# %%
env.render()

# %%
env.stops
# Out:
# [0]

# %%
for i in [0,1,2,3]:
    env.step(i)

# %%
env.render()

# %%
import sys
sys.path.append("../")

from delivery import run_episode,DeliveryQAgent,run_n_episodes

# %%
env = DeliveryEnvironment(n_arrets = 5,method = "distance")
# Out:
# Initialized Delivery Environment with 5 random stops
# Target metric for optimization is distance

# %%
agent = DeliveryQAgent(env.observation_space,env.action_space)

# %%
run_n_episodes(env,agent,"training_5_arrets.gif")
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 run_n_episodes(env,agent,"training_5_arrets.gif")
#
# File ~\PycharmProjects\Logistics optimization\delivery.py:284, in run_n_episodes(env, agent, name, n_episodes, render_each, fps)
#     280 # Experience replay
#     281 for i in tqdm_notebook(range(n_episodes)):
#     282
#     283     # Run the episode
# --> 284     env, agent, episode_reward = run_episode(env, agent, verbose=0)
#     285     rewards.append(episode_reward)
#     287     if i % render_each == 0:
#
# File ~\PycharmProjects\Logistics optimization\delivery.py:246, in run_episode(env, agent, verbose)
#     243 s = env.reset()
#     244 agent.reset_memory()
# --> 246 max_step = env.n_stops
#     247 episode_reward = 0
#     249 i = 0
#
# ...

# %%
env = DeliveryEnvironment(n_arrets = 100,method = "traffic_box",box_size = 0.6,traffic_intensity = 100)
# Out:
# Initialized Delivery Environment with 100 random stops
# Target metric for optimization is traffic_box

# %%
agent = DeliveryQAgent(env.observation_space,env.action_space)

# %%
run_n_episodes(env,agent,"training_100_arrets_traffic.gif")
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 run_n_episodes(env,agent,"training_100_stops_traffic.gif")
#
# File ~\PycharmProjects\Logistics optimization\delivery.py:284, in run_n_episodes(env, agent, name, n_episodes, render_each, fps)
#     280 # Experience replay
#     281 for i in tqdm_notebook(range(n_episodes)):
#     282
#     283     # Run the episode
# --> 284     env, agent, episode_reward = run_episode(env, agent, verbose=0)
#     285     rewards.append(episode_reward)
#     287     if i % render_each == 0:
#
# File ~\PycharmProjects\Logistics optimization\delivery.py:246, in run_episode(env, agent, verbose)
#     243 s = env.reset()
#     244 agent.reset_memory()
# --> 246 max_step = env.n_stops
#     247 episode_reward = 0
#     249 i = 0
#
# ...
