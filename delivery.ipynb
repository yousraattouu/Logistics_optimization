# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import time
from tqdm import tqdm_notebook
# %matplotlib inline
# %load_ext autoreload
# %autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from delivery import *

# %%
env = DeliveryEnvironment(n_stops = 10)
# Out:
# Initialized Delivery Environment with 10 random stops
# Target metric for optimization is distance

# %%
env.render()

# %%
env.stops
# Out:
# [8]

# %%
for i in [0,1,2,3,4,5,6,7]:
    env.step(i)

# %%
env.render()

# %%
import sys
sys.path.append("../")

from delivery import run_episode,DeliveryQAgent,run_n_episodes

# %%
env = DeliveryEnvironment(n_stops = 5,method = "distance")
# Out:
# Initialized Delivery Environment with 5 random stops
# Target metric for optimization is distance

# %%
agent = DeliveryQAgent(env.observation_space,env.action_space)

# %%
run_n_episodes(env,agent,"training_5_arrets.gif")
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# (<delivery.DeliveryEnvironment at 0x2cb753708d0>,
#  <q_agent.DeliveryQAgent at 0x2cb75e83590>)

# %%
env = DeliveryEnvironment(n_stops = 500,method = "traffic_box",box_size = 0.6,traffic_intensity = 100)
# Out:
# Initialized Delivery Environment with 500 random stops
# Target metric for optimization is traffic_box

# %%
agent = DeliveryQAgent(env.observation_space,env.action_space)

# %%
run_n_episodes(env,agent,"training_100_arrets_traffic.gif")
